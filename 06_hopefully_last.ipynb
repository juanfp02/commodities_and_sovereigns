# %% [markdown]
# # Empirical design

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox

# %% [markdown]
# ## Paths

# %%
PANEL_PATH = "data/processed/merton_panel.csv"
panel = pd.read_csv(PANEL_PATH, parse_dates=['date'])

OIL_PATH = 'data/processed/Oil/oil_prices_datastream.csv'
oil_df = pd.read_csv(OIL_PATH, parse_dates=['Date'])

OVX_PATH = 'data/processed/Macroeconomic_variables/OVXCLS.csv'
ovx_df = pd.read_csv(OVX_PATH, parse_dates=['Date'])
ovx_df.set_index('Date',inplace=True)
# Out:
# /var/folders/wy/gjw_3_n51t748hfngpz4zf0w0000gn/T/ipykernel_96515/3564100602.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   oil_df = pd.read_csv(OIL_PATH, parse_dates=['Date'])

# %% [markdown]
# ## STEP 1: Extract the unexpected component from OVX

# %%
df = ovx_df.resample('W-FRI').asof(ovx_df.index)
df
