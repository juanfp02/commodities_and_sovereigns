# %%
import pandas as pd

# %%
df = pd.read_csv(
    'mscicountryindex.csv', delimiter=','
)

df['Date'] = pd.to_datetime(df['Date'])

df.set_index(df['Date'],inplace=True)
# Out:
# /var/folders/wy/gjw_3_n51t748hfngpz4zf0w0000gn/T/ipykernel_64909/3385198415.py:5: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#                  Date   Kuwait     India  Indonesia    Taiwan  United States  \
# Date
# 1999-12-31 1999-12-31      NaN   318.056    535.724  1330.338        907.301
# 2000-01-03 2000-01-03      NaN   341.101    535.724  1328.727        900.233
# 2000-01-04 2000-01-04      NaN   350.405    539.374  1412.912        863.582
# 2000-01-05 2000-01-05      NaN   342.164    515.989  1419.351        863.731
# 2000-01-06 2000-01-06      NaN   342.967    515.961  1427.086        855.496
# ...               ...      ...       ...        ...       ...            ...
# 2024-12-25 2024-12-25  570.648  2449.703   1098.383  2925.613       3951.045
# 2024-12-26 2024-12-26  570.819  2451.006   1098.383  2926.300       3951.252
# 2024-12-27 2024-12-27  571.097  2444.870   1093.211  2932.398       3906.430
# 2024-12-30 2024-12-30  571.480  2434.260   1101.649  2919.074       3865.437
# 2024-12-31 2024-12-31  570.894  2434.962   1104.387  2894.834       3849.995
#
# ...
