# %%
import pandas as pd

# %%
df = pd.read_csv('QEDS_SDDS.csv', delimiter=';')

# %%
df
# Out:
#        Country Name Country Code Cleaned_Name  \
# 0       Afghanistan          AFG  Afghanistan
# 1       Afghanistan          AFG  Afghanistan
# 2       Afghanistan          AFG  Afghanistan
# 3       Afghanistan          AFG  Afghanistan
# 4       Afghanistan          AFG  Afghanistan
# ...             ...          ...          ...
# 232195       Zambia          ZMB       Zambia
# 232196       Zambia          ZMB       Zambia
# 232197       Zambia          ZMB       Zambia
# 232198       Zambia          ZMB       Zambia
# 232199       Zambia          ZMB       Zambia
#
#                                            Indicator Name  \
# 0       Ext. Assets in Debt Instruments, All Sectors, ...
# 1       Ext. Assets in Debt Instruments, Central Bank,...
# 2       Ext. Assets in Debt Instruments, Central Bank,...
# 3       Ext. Assets in Debt Instruments, Central Bank,...
# 4       Ext. Assets in Debt Instruments, Central Bank,...
# ...
