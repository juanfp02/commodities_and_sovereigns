# %%
import pandas as pd

# %%
df_daily = pd.read_csv('Daily_CDS_Refinitiv_EOD.csv')
df_daily['Date'] = pd.to_datetime(df_daily['Date'], format='%d.%m.%Y')
df_daily.set_index('Date', inplace=True)

df_weekly = df_daily.asfreq('W-FRI').ffill()

df_daily.to_csv('Daily_CDS.csv')
df_weekly.to_csv('Weekly_CDS.csv')

# %%
df_friday_filled = df.asfreq('W-FRI').ffill()

# %%
df_friday_filled
# Out:
#             United States  United Kingdom     Japan  Australia     China  \
# Date
# 1999-12-31            NaN             NaN       NaN        NaN       NaN
# 2000-01-07            NaN             NaN       NaN        NaN       NaN
# 2000-01-14            NaN             NaN       NaN        NaN       NaN
# 2000-01-21            NaN             NaN       NaN        NaN       NaN
# 2000-01-28            NaN             NaN       NaN        NaN       NaN
# ...                   ...             ...       ...        ...       ...
# 2024-11-29       29.67000           14.21  21.25000      10.20  64.73000
# 2024-12-06       29.67000           14.16  21.14999      10.11  62.70000
# 2024-12-13       29.24001           13.98  21.14999      10.11  61.70000
# 2024-12-20       29.22000           14.17  21.28000      10.11  65.74001
# 2024-12-27       29.24001           14.09  21.19000      10.11  65.70000
#
#             France  Germany  India  Italy    Turkey  ...  El Salvador  \
# ...
